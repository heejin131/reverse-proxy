# %%
import pandas as pd

# %%
df = pd.read_csv("docker_stats.csv")
df["Timestamp"] = pd.to_datetime(df["Timestamp"], unit='s')

# %%
df
# Out:
#              Timestamp     Container                        Name  \
# 0  2025-02-27 02:11:27  29d3a5c70147       reverse-proxy-agent-1
# 1  2025-02-27 02:11:27  ebabb3d2467e  reverse-proxy-controller-1
# 2  2025-02-27 02:11:40  29d3a5c70147       reverse-proxy-agent-1
# 3  2025-02-27 02:11:40  ebabb3d2467e  reverse-proxy-controller-1
# 4  2025-02-27 02:11:52  29d3a5c70147       reverse-proxy-agent-1
# 5  2025-02-27 02:11:52  ebabb3d2467e  reverse-proxy-controller-1
# 6  2025-02-27 02:13:20  29d3a5c70147       reverse-proxy-agent-1
# 7  2025-02-27 02:13:20  ebabb3d2467e  reverse-proxy-controller-1
# 8  2025-02-27 02:13:33  29d3a5c70147       reverse-proxy-agent-1
# 9  2025-02-27 02:13:33  ebabb3d2467e  reverse-proxy-controller-1
# 10 2025-02-27 02:13:45  29d3a5c70147       reverse-proxy-agent-1
# 11 2025-02-27 02:13:45  ebabb3d2467e  reverse-proxy-controller-1
# 12 2025-02-27 02:13:58  29d3a5c70147       reverse-proxy-agent-1
# ...
